# %%
# 我们着重讨论不同区域的显著性影响因素
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/86187/Desktop/新加坡国立大学暑期学校相关文件/data_cleaned.csv")
data.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  297597.000000  297597.000000  2.975970e+05  152184.000000
# mean      116.418767      39.949761  1.126275e+12      29.469701
# std         0.110999       0.091533  1.331619e+12      50.394467
# min       116.072514      39.627030  1.111030e+12       1.000000
# 25%       116.345863      39.893200  1.111030e+12       1.000000
# 50%       116.416780      39.934530  1.111030e+12       7.000000
# 75%       116.476921      40.003156  1.111030e+12      38.000000
# max       116.711337      40.252758  1.184870e+14    1677.000000
#
#            followers          price     livingRoom    drawingRoom  \
# count  297597.000000  297597.000000  297597.000000  297597.000000
# mean        0.015039       0.391045       2.011102       1.171107
# std         0.030417       0.178332       0.764922       0.512581
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.258747       1.000000       1.000000
# 50%         0.004374       0.357607       2.000000       1.000000
# 75%         0.016623       0.485556       2.000000       1.000000
# max         1.000000       1.000000       8.000000       5.000000
#
#              kitchen       bathRoom  ...  buildingStructure    ladderRatio  \
# count  297597.000000  297597.000000  ...      297597.000000  297597.000000
# mean        0.995131       1.182351  ...           4.421473       0.381856
# std         0.100335       0.423099  ...           1.907456       0.176411
# min         0.000000       0.000000  ...           1.000000       0.014000
# 25%         1.000000       1.000000  ...           2.000000       0.250000
# 50%         1.000000       1.000000  ...           6.000000       0.333000
# 75%         1.000000       1.000000  ...           6.000000       0.500000
# max         3.000000       7.000000  ...           6.000000       5.000000
#
#             elevator         subway       district  communityAverage  \
# count  297597.000000  297597.000000  297597.000000     297597.000000
# mean        0.570624       0.602388       6.748516      63696.710585
# std         0.494988       0.489405       2.811945      22153.499402
# min         0.000000       0.000000       1.000000      10847.000000
# 25%         0.000000       0.000000       6.000000      46505.000000
# 50%         1.000000       1.000000       7.000000      59025.000000
# 75%         1.000000       1.000000       8.000000      75858.000000
# max         1.000000       1.000000      13.000000     183109.000000
#
#        tradeTimeModefiy  Original_price  Original_followers  attractiveness
# count     297597.000000   297597.000000       297597.000000   297597.000000
# mean      735621.421896    42715.008611           17.189713        0.391045
# std          597.390522    19476.512214           34.766471        0.178332
# min       734046.000000        7.000000            0.000000        0.000000
# 25%       735124.000000    28266.000000            0.000000        0.258747
# 50%       735769.000000    39063.000000            5.000000        0.357607
# 75%       736091.000000    53037.000000           19.000000        0.485556
# max       736628.000000   109222.000000         1143.000000        1.000000
#
# [8 rows x 24 columns]

# %%
data.shape
# Out:
# (297597, 25)

# %%
data['totalRoom'] = data['livingRoom'] + data['drawingRoom'] + data['kitchen'] + data['bathRoom']
data['houseAge'] = data['tradeTimeModefiy']//365 - data['constructionTime']
data['houseCondition'] = data['renovationCondition'] + data['subway'] + data['elevator']

# %%
import folium
# 创建地图对象，设置初始位置和缩放级别
m = folium.Map(location=[39.906217, 116.3912757], zoom_start=13)
# 在地图上添加一个标记点
folium.Marker([39.906217, 116.3912757], popup='Beijing').add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2433fd1e045e50a3f7211548d79d7f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2433fd1e045e50a3f7211548d79d7f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2433fd1e045e50a3f7211548d79d7f3 = L.map(
#                 &quot;map_c2433fd1e045e50a3f7211548d79d7f3&quot;,
#                 {
#                     center: [39.906217, 116.3912757],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08823737522715a7d651ebcb704cedb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_08823737522715a7d651ebcb704cedb1.addTo(map_c2433fd1e045e50a3f7211548d79d7f3);
#
#
#             var marker_329ca546002138ddfd6708ac531cacbd = L.marker(
#                 [39.906217, 116.3912757],
#                 {}
#             ).addTo(map_c2433fd1e045e50a3f7211548d79d7f3);
#
#
#         var popup_6c2c0b9f95c3fdaa751e3d5ae20ee5f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_566dba6b20aa5900abb8c2b6fb2d2ce6 = $(`&lt;div id=&quot;html_566dba6b20aa5900abb8c2b6fb2d2ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beijing&lt;/div&gt;`)[0];
#                 popup_6c2c0b9f95c3fdaa751e3d5ae20ee5f3.setContent(html_566dba6b20aa5900abb8c2b6fb2d2ce6);
#
#
#
#         marker_329ca546002138ddfd6708ac531cacbd.bindPopup(popup_6c2c0b9f95c3fdaa751e3d5ae20ee5f3)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 对district进行分组并计算每个区域的样本个数
district_counts = data.groupby('district').size()
# 绘制柱状图
district_counts.plot(kind='bar')

plt.xlabel('District')
plt.ylabel('Number of Properties')
plt.title('Number of Properties by District')
plt.xticks(range(len(district_counts)), ['Dongcheng', 'Fengtai', 'Tongzhou', 'Daxing', 'Fangshan', 'Changping', 'Chaoyang', 'Haidian', 'Shijingshan', 'Xicheng', 'Pinggu', 'Mentougou', 'Shunyi'], rotation=45)
plt.show()

# %%
# 我们分区块研究影响房价的显著因素
# 东城区
from folium.plugins import MarkerCluster
Tongzhou_data = data[data['district'] == 3]
map_center = [Tongzhou_data.iloc[0]['Lat'], Tongzhou_data.iloc[0]['Lng']]
m = folium.Map(location=map_center, zoom_start=12)
# 创建一个 MarkerCluster 对象
marker_cluster = MarkerCluster().add_to(m)
# 遍历为每个点添加标记到 MarkerCluster 中，而不是直接添加到地图上
for index, row in Tongzhou_data.iterrows():
    folium.Marker([row['Lat'], row['Lng']]).add_to(marker_cluster)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f2252bcdea1cec04f77296f59f0cbb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f2252bcdea1cec04f77296f59f0cbb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f2252bcdea1cec04f77296f59f0cbb4 = L.map(
#                 &quot;map_0f2252bcdea1cec04f77296f59f0cbb4&quot;,
#                 {
#                     center: [39.810115, 116.497474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4636c96f5a9bc71ebc8ce2510a1c2a5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4636c96f5a9bc71ebc8ce2510a1c2a5a.addTo(map_0f2252bcdea1cec04f77296f59f0cbb4);
#
#
#             var marker_cluster_f9428de3d35e809fbd98fda667dcd046 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8951bf8f9183f6595c9f2ad082f421cd = L.marker(
#                 [39.810115, 116.497474],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_49c010d4e74f03682d627a05a3bd83cc = L.marker(
#                 [39.806241, 116.50642],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_a0b4bf71acc79c4e94c499084000b968 = L.marker(
#                 [39.805889, 116.500382],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_222deee4c3c4b13d77c94fa2787eccde = L.marker(
#                 [39.806241, 116.50642],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_a43a8853e0053db71e45ff792317500f = L.marker(
#                 [39.80512, 116.485785],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_5142ffd8e82de25e589d65847faa1b11 = L.marker(
#                 [39.803512, 116.479443],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_309c8d440ac5cf52f9b77aa0a496e1c7 = L.marker(
#                 [39.798212, 116.490411],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_44ea47a2dba5fa379aeda7e328b4c293 = L.marker(
#                 [39.810115, 116.497474],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_d76c8da21717c33d6e46b5f9937d2f8e = L.marker(
#                 [39.795716, 116.504579],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_220fd07670198dcdaa99dcd36b7c2360 = L.marker(
#                 [39.795716, 116.504579],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_99741c0a1a667dc0700fe76b996d394b = L.marker(
#                 [39.7967, 116.498417],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_001108378dc1361fb008a22c3a18fea8 = L.marker(
#                 [39.806241, 116.50642],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_0cef024884ccb2153a67672e2c3c3497 = L.marker(
#                 [39.803512, 116.479443],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_08a497654edbe1610a27c23ef0ee499b = L.marker(
#                 [39.804081, 116.497256],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_5ad154f9ad5b7727d43a06493300d41d = L.marker(
#                 [39.80855, 116.499592],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_3ca9ea165fcedc5a95f416f6f04d0c3a = L.marker(
#                 [39.795716, 116.504579],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809fbd98fda667dcd046);
#
#
#             var marker_2bbe121e2cb8c35811a24daed57624de = L.marker(
#                 [39.795716, 116.504579],
#                 {}
#             ).addTo(marker_cluster_f9428de3d35e809f

# %%
from folium.plugins import HeatMap
# 东城区
# 我们先观察房屋价格在地理空间中的分布情况
map_center = [Tongzhou_data.iloc[0]['Lat']-0.03, Tongzhou_data.iloc[0]['Lng']]
m = folium.Map(location=map_center, zoom_start=12)
# 权重设置为每个点的price
heat_data = [[row['Lat'], row['Lng'], row['attractiveness']] for index, row in Tongzhou_data.iterrows()]
# 创建热度图并添加到地图上，使用price作为权重
HeatMap(heat_data,blur=4, radius=8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8554f54169aada02ca71f6cad43dc642 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8554f54169aada02ca71f6cad43dc642&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8554f54169aada02ca71f6cad43dc642 = L.map(
#                 &quot;map_8554f54169aada02ca71f6cad43dc642&quot;,
#                 {
#                     center: [39.780115, 116.497474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e45fab68f1c9d38fec19f720b993d20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e45fab68f1c9d38fec19f720b993d20.addTo(map_8554f54169aada02ca71f6cad43dc642);
#
#
#             var heat_map_dd6ae790346bd19d53ae160cebe2c604 = L.heatLayer(
#                 [[39.810115, 116.497474, 0.1802316531611958], [39.806241, 116.50642, 0.1891956233118161], [39.805889, 116.500382, 0.1847365288650826], [39.806241, 116.50642, 0.1765783088403607], [39.80512, 116.485785, 0.1900105296891452], [39.803512, 116.479443, 0.2039829693723389], [39.798212, 116.490411, 0.1913473423980222], [39.810115, 116.497474, 0.1976559996337499], [39.795716, 116.504579, 0.1895435608661813], [39.795716, 116.504579, 0.1878038730943551], [39.7967, 116.498417, 0.1785926841551069], [39.806241, 116.50642, 0.0237696287140044], [39.803512, 116.479443, 0.1677699949640617], [39.804081, 116.497256, 0.1524424300691297], [39.80855, 116.499592, 0.1504097422515222], [39.795716, 116.504579, 0.1751316211143158], [39.795716, 116.504579, 0.1444307100672984], [39.807081, 116.498756, 0.1389918967174838], [39.796534, 116.495541, 0.1354301149109554], [39.80512, 116.485785, 0.1532207114407361], [39.804081, 116.497256, 0.1522867737948084], [39.755236, 116.546899, 0.1649773382777091], [39.795716, 116.504579, 0.1297074577667902], [39.798212, 116.490411, 0.1320789268873323], [39.799347, 116.501794, 0.1773565902119672], [39.799347, 116.501794, 0.1462436478505699], [39.795716, 116.504579, 0.1362816462940072], [39.810115, 116.497474, 0.158870118573456], [39.803512, 116.479443, 0.1789131529551801], [39.80512, 116.485785, 0.1608844938882021], [39.755625, 116.550348, 0.1160554868836698], [39.804081, 116.497256, 0.1519571487433045], [39.80855, 116.499592, 0.1514993361717712], [39.805889, 116.500382, 0.1247997069999542], [39.7967, 116.498417, 0.1623220253628164], [39.795716, 116.504579, 0.1788307466923041], [39.80512, 116.485785, 0.1914205924094675], [39.795716, 116.504579, 0.183363091150483], [39.760284, 116.54671, 0.1051687039326099], [39.795716, 116.504579, 0.1766607151032367], [39.803512, 116.479443, 0.1813761845900288], [39.795716, 116.504579, 0.1790413404752094], [39.80855, 116.499592, 0.1565810557157899], [39.803512, 116.479443, 0.1804605594469624], [39.80855, 116.499592, 0.1662775259808634], [39.795716, 116.504579, 0.1893695920889987], [39.810115, 116.497474, 0.1853683102137984], [39.760284, 116.54671, 0.0990981092340795], [39.805889, 116.500382, 0.1395138030490317], [39.755625, 116.550348, 0.0610813532939614], [39.810115, 116.497474, 0.1629812754658243], [39.795716, 116.504579, 0.1526255550977429], [39.810115, 116.497474, 0.1629812754658243], [39.795716, 116.504579, 0.1543560866181385], [39.803512, 116.479443, 0.1973721558393993], [39.7967, 116.498417, 0.1722199331593645], [39.803512, 116.479443, 0.1872728105113766], [39.798212, 116.490411, 0.1764318088174701], [39.795716, 116.504579, 0.1987639060568603], [39.805889, 116.500382, 0.1525889300920203], [39.80512, 116.485785, 0.1596575561964931], [39.805889, 116.500382, 0.1332783958247493], [39.804081, 116.497256, 0.1879503731172458], [39.810115, 116.497474, 0.1712676830105754], [39.810115, 116.497474, 0.1636313693174014], [39.807081, 116.498756, 0.1584672435105068], [39.799347, 116.501794, 0.2437302568328526], [39.805889, 116.500382, 0.1681362450212883], [39.795716, 116.504579, 0.2040653756352149], [39.804081, 116.497256, 0.1918234674724168], [39.810115, 116.497474, 0.1650048070320011], [39.760284, 116.54671, 0.1246623632284942], [39.795716, 116.504579, 0.1663874009980314], [39.80512, 116.485785, 0.1937096552671336], [39.805889, 116.500382, 0.1284530513207892], [39.795716, 116.504579, 0.1699308703016984], [39.795716, 116.504579, 0.178153184086435], [39.798212, 116.490411, 0.1905965297807078], [39.80855, 116.499592, 0.1620381815684658], [39.798212, 116.490411, 0.1936547177585496], [39.755625, 116.550348, 0.119159456118665], [39.795716, 116.504579, 0.2167010026095316], [39.798212, 116.490411, 0.1872728105113766], [39.795716, 116.504579, 0.2027010941720459], [39.755236, 116.546899, 0.1242961131712676], [39.810115, 116.497474, 0.2199331593645561], [39.803512, 116.479443, 0.2068030948129835], [39.810115, 116.49

# %%
# 我们在东城区的范围内研究房价的显著影响因素
# 东城区
import seaborn as sns
# 使用Seaborn绘制ladderRatio与attarctiveness的关系
sns.scatterplot(data=Tongzhou_data, x='ladderRatio', y='attractiveness')
plt.title('Ladder Ratio vs Attractiveness in Dongcheng')
plt.xlabel('Ladder Ratio')
plt.ylabel('Attractiveness')
plt.show()

# %%
# 计算ladderRatio和attractiveness之间的相关系数
correlation_matrix = Tongzhou_data[['ladderRatio', 'attractiveness']].corr()
# 打印相关系数矩阵
print(correlation_matrix)
# 从相关系数的角度看一般条件下ladderRatio在东城区不是一个显著影响房屋吸引力的因素
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000        0.133309
# attractiveness     0.133309        1.000000

# %%
# 我们再观察东城区的房价与楼层高度的关系
high_floor = Tongzhou_data[Tongzhou_data['floor'] > 10]
low_floor = Tongzhou_data[Tongzhou_data['floor'] <= 10]
print("东城区高层建筑共{high_floor}个，低层建筑共{low_floor}个,高层建筑占比为{high_floor_ratio:.2f}%".format(high_floor=len(high_floor), low_floor=len(low_floor), high_floor_ratio=len(high_floor)/len(Tongzhou_data)*100))
# Out:
# 东城区高层建筑共1045个，低层建筑共1164个,高层建筑占比为47.31%

# %%
# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie([len(high_floor), len(low_floor)], labels=['High Floor', 'Low Floor'], autopct='%1.1f%%', startangle=140)
plt.title('Dongcheng Building Type Distribution')
plt.show()

# %%
# 计算floor和attractivness之间的相关系数
correlation_matrix = Tongzhou_data[['floor', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                    floor  attractiveness
# floor           1.000000        0.043431
# attractiveness  0.043431        1.000000

# %%
# 我们在东城区的范围内研究房价的显著影响因素
# 东城区
# 使用Seaborn绘制ladderRatio与attarctiveness的关系
sns.scatterplot(data=Tongzhou_data, x='floor', y='attractiveness')
plt.title('Floor vs Attarctiveness in Dongcheng')
plt.xlabel('Floor')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 发现在东城区中整体上floor和房屋的受欢迎程度没有关联
# 计算在高层条件下ladderRatio和attractiveness之间的相关系数
correlation_matrix = high_floor[['ladderRatio', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000        0.292512
# attractiveness     0.292512        1.000000

# %%
correlation_matrix = low_floor[['ladderRatio', 'attractiveness']].corr()
print(correlation_matrix)
# 对于低层建筑, ladderRatio和attractiveness之间的关联性相较于高层建筑要更弱,虽然面对高层建筑时人们会考虑人均楼梯数目但总体来说不显著
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000       -0.023326
# attractiveness    -0.023326        1.000000

# %%
sns.scatterplot(data=Tongzhou_data, x='communityAverage', y='attractiveness')
plt.title('CommunityAverage vs Attarctiveness in Dongcheng')
plt.xlabel('CommunityAverage')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 研究communityAverage与attractiveness之间的关联度
correlation_matrix = Tongzhou_data[['communityAverage', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   communityAverage  attractiveness
# communityAverage          1.000000        0.319603
# attractiveness            0.319603        1.000000

# %%
sns.scatterplot(data=Tongzhou_data, x='totalRoom', y='attractiveness')
plt.title('TotalRoom vs Attarctiveness in Dongcheng')
plt.xlabel('TotalRoom')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 研究totalRoom与attractiveness之间的关联度
correlation_matrix = Tongzhou_data[['totalRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 totalRoom  attractiveness
# totalRoom        1.000000       -0.011265
# attractiveness  -0.011265        1.000000

# %%
# 研究totalRoom与attractiveness之间的关联度
correlation_matrix = Tongzhou_data[['totalRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 totalRoom  attractiveness
# totalRoom        1.000000       -0.011265
# attractiveness  -0.011265        1.000000

# %%
# 分别计算每种房间的总数
total_livingRoom = Tongzhou_data['livingRoom'].sum()
total_drawingRoom = Tongzhou_data['drawingRoom'].sum()
total_kitchen = Tongzhou_data['kitchen'].sum()
total_bathroom = Tongzhou_data['bathRoom'].sum()
# 将计算结果合并为一个新的Series
room_totals = pd.Series({
    'Living Room': total_livingRoom,
    'Drawing Room': total_drawingRoom,
    'Kitchen': total_kitchen,
    'Bathroom': total_bathroom
})
room_totals.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution in Dongcheng')
plt.ylabel('')
plt.show()

# %%
# 我们从一般的角度出发研究房间类型对吸引力的影响
correlation_matrix = Tongzhou_data[['bathRoom','kitchen','drawingRoom','livingRoom' ,'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  livingRoom  attractiveness
# bathRoom        1.000000  0.104010     0.607722    0.755988       -0.023901
# kitchen         0.104010  1.000000     0.079733    0.077968        0.028242
# drawingRoom     0.607722  0.079733     1.000000    0.717044       -0.035366
# livingRoom      0.755988  0.077968     0.717044    1.000000        0.014479
# attractiveness -0.023901  0.028242    -0.035366    0.014479        1.000000

# %%
big_family = Tongzhou_data[Tongzhou_data['livingRoom'] >= 3]
# 我们再进一步研究大的家庭对不同种类房间的需求
correlation_matrix = big_family[['bathRoom','kitchen','drawingRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  attractiveness
# bathRoom        1.000000  0.090035     0.181670       -0.003289
# kitchen         0.090035  1.000000     0.022261       -0.047749
# drawingRoom     0.181670  0.022261     1.000000       -0.161953
# attractiveness -0.003289 -0.047749    -0.161953        1.000000

# %%
small_family = Tongzhou_data[Tongzhou_data['livingRoom'] < 3]
correlation_matrix = small_family[['bathRoom','kitchen','drawingRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  attractiveness
# bathRoom        1.000000  0.099247     0.394090        0.004508
# kitchen         0.099247  1.000000     0.066025        0.058332
# drawingRoom     0.394090  0.066025     1.000000        0.013795
# attractiveness  0.004508  0.058332     0.013795        1.000000

# %%
# 交易时房龄对吸引力的影响
correlation_matrix = Tongzhou_data[['constructionTime','houseAge','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   constructionTime  houseAge  attractiveness
# constructionTime          1.000000 -0.916445        0.047270
# houseAge                 -0.916445  1.000000        0.206255
# attractiveness            0.047270  0.206255        1.000000

# %%
correlation_matrix = Tongzhou_data[['houseCondition','houseAge','constructionTime','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   houseCondition  houseAge  constructionTime  attractiveness
# houseCondition          1.000000  0.016095          0.191580        0.294726
# houseAge                0.016095  1.000000         -0.916445        0.206255
# constructionTime        0.191580 -0.916445          1.000000        0.047270
# attractiveness          0.294726  0.206255          0.047270        1.000000

# %%
correlation_matrix = high_floor[['elevator','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 elevator  attractiveness
# elevator             NaN             NaN
# attractiveness       NaN             1.0

# %%
type_mapping = {
    1: 'tower',
    2: 'bungalow',
    3: 'combination of plate and tower',
    4: 'plate'
}
Tongzhou_data['buildingType'] = Tongzhou_data['buildingType'].map(type_mapping)
building_type_counts = Tongzhou_data['buildingType'].value_counts()
building_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Building Type Distribution')
plt.ylabel('')
plt.show()
# Out:
# C:\Users\86187\AppData\Local\Temp\ipykernel_4604\706490599.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tongzhou_data['buildingType'] = Tongzhou_data['buildingType'].map(type_mapping)

# %%
# 计算每种房屋建筑结构类型的attractiveness平均值
attractiveness_avg = Tongzhou_data.groupby('buildingType')['attractiveness'].mean().sort_values(ascending=False)
print(attractiveness_avg)
attractiveness_avg.plot(kind='bar')
plt.title('Average Attractiveness by House Type')
plt.xlabel('Building Type')
plt.ylabel('Average Attractiveness')
plt.show()
# Out:
# buildingType
# plate                             0.300498
# tower                             0.283279
# combination of plate and tower    0.277709
# Name: attractiveness, dtype: float64

# %%
Tongzhou_data= Tongzhou_data[Tongzhou_data['buildingStructure']!=1]
Tongzhou_data['buildingStructure']
# Out:
# 70        6
# 153       6
# 365       6
# 909       6
# 1374      2
#          ..
# 297016    2
# 297136    6
# 297138    2
# 297224    4
# 297535    6
# Name: buildingStructure, Length: 2209, dtype: int64

# %%
type_mapping = {
    2:"mixed",
    3:"brick and wood", 
    4:"brick and concrete", 
    5:"steel", 
    6:"steel-concrete composite"
}
Tongzhou_data['buildingStructure'] = Tongzhou_data['buildingStructure'].map(type_mapping)
building_type_counts = Tongzhou_data['buildingStructure'].value_counts()
explode_values = (0, 0, 0.3, 0.2, 0.1)
building_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Building Structure Distribution')
plt.ylabel('')
plt.show()

# %%
# 计算每种房屋建筑结构类型的attractiveness平均值
attractiveness_avg = Tongzhou_data.groupby('buildingStructure')['attractiveness'].mean().sort_values(ascending=False)
print(attractiveness_avg)
attractiveness_avg.plot(kind='bar')
plt.title('Average Attractiveness by Building Structure')
plt.xlabel('Building Structure')
plt.ylabel('Average Attractiveness')
plt.show()
# Out:
# buildingStructure
# mixed                       0.305876
# steel-concrete composite    0.288365
# brick and concrete          0.263005
# Name: attractiveness, dtype: float64
