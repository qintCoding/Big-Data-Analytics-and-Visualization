# %%
# 我们着重讨论不同区域的显著性影响因素
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/86187/Desktop/新加坡国立大学暑期学校相关文件/data_cleaned.csv")
data.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  297597.000000  297597.000000  2.975970e+05  152184.000000
# mean      116.418767      39.949761  1.126275e+12      29.469701
# std         0.110999       0.091533  1.331619e+12      50.394467
# min       116.072514      39.627030  1.111030e+12       1.000000
# 25%       116.345863      39.893200  1.111030e+12       1.000000
# 50%       116.416780      39.934530  1.111030e+12       7.000000
# 75%       116.476921      40.003156  1.111030e+12      38.000000
# max       116.711337      40.252758  1.184870e+14    1677.000000
#
#            followers          price     livingRoom    drawingRoom  \
# count  297597.000000  297597.000000  297597.000000  297597.000000
# mean        0.015039       0.391045       2.011102       1.171107
# std         0.030417       0.178332       0.764922       0.512581
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.258747       1.000000       1.000000
# 50%         0.004374       0.357607       2.000000       1.000000
# 75%         0.016623       0.485556       2.000000       1.000000
# max         1.000000       1.000000       8.000000       5.000000
#
#              kitchen       bathRoom  ...  buildingStructure    ladderRatio  \
# count  297597.000000  297597.000000  ...      297597.000000  297597.000000
# mean        0.995131       1.182351  ...           4.421473       0.381856
# std         0.100335       0.423099  ...           1.907456       0.176411
# min         0.000000       0.000000  ...           1.000000       0.014000
# 25%         1.000000       1.000000  ...           2.000000       0.250000
# 50%         1.000000       1.000000  ...           6.000000       0.333000
# 75%         1.000000       1.000000  ...           6.000000       0.500000
# max         3.000000       7.000000  ...           6.000000       5.000000
#
#             elevator         subway       district  communityAverage  \
# count  297597.000000  297597.000000  297597.000000     297597.000000
# mean        0.570624       0.602388       6.748516      63696.710585
# std         0.494988       0.489405       2.811945      22153.499402
# min         0.000000       0.000000       1.000000      10847.000000
# 25%         0.000000       0.000000       6.000000      46505.000000
# 50%         1.000000       1.000000       7.000000      59025.000000
# 75%         1.000000       1.000000       8.000000      75858.000000
# max         1.000000       1.000000      13.000000     183109.000000
#
#        tradeTimeModefiy  Original_price  Original_followers  attractiveness
# count     297597.000000   297597.000000       297597.000000   297597.000000
# mean      735621.421896    42715.008611           17.189713        0.391045
# std          597.390522    19476.512214           34.766471        0.178332
# min       734046.000000        7.000000            0.000000        0.000000
# 25%       735124.000000    28266.000000            0.000000        0.258747
# 50%       735769.000000    39063.000000            5.000000        0.357607
# 75%       736091.000000    53037.000000           19.000000        0.485556
# max       736628.000000   109222.000000         1143.000000        1.000000
#
# [8 rows x 24 columns]

# %%
data.shape
# Out:
# (297597, 25)

# %%
data['totalRoom'] = data['livingRoom'] + data['drawingRoom'] + data['kitchen'] + data['bathRoom']
data['houseAge'] = data['tradeTimeModefiy']//365 - data['constructionTime']
data['houseCondition'] = data['renovationCondition'] + data['subway'] + data['elevator']

# %%
import folium
# 创建地图对象，设置初始位置和缩放级别
m = folium.Map(location=[39.906217, 116.3912757], zoom_start=13)
# 在地图上添加一个标记点
folium.Marker([39.906217, 116.3912757], popup='Beijing').add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d3c34afe64ebbb8f8698039a3f97a78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d3c34afe64ebbb8f8698039a3f97a78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d3c34afe64ebbb8f8698039a3f97a78 = L.map(
#                 &quot;map_2d3c34afe64ebbb8f8698039a3f97a78&quot;,
#                 {
#                     center: [39.906217, 116.3912757],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d48219266cf067ca43f9eec3b52709d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d48219266cf067ca43f9eec3b52709d.addTo(map_2d3c34afe64ebbb8f8698039a3f97a78);
#
#
#             var marker_b8842ecf114e0de0d10df5f2ece8606f = L.marker(
#                 [39.906217, 116.3912757],
#                 {}
#             ).addTo(map_2d3c34afe64ebbb8f8698039a3f97a78);
#
#
#         var popup_c72379c555b01e930a72377f65ee1c36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f08c904e05025b9222d771dbd84527a6 = $(`&lt;div id=&quot;html_f08c904e05025b9222d771dbd84527a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beijing&lt;/div&gt;`)[0];
#                 popup_c72379c555b01e930a72377f65ee1c36.setContent(html_f08c904e05025b9222d771dbd84527a6);
#
#
#
#         marker_b8842ecf114e0de0d10df5f2ece8606f.bindPopup(popup_c72379c555b01e930a72377f65ee1c36)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 对district进行分组并计算每个区域的样本个数
district_counts = data.groupby('district').size()
# 绘制柱状图
district_counts.plot(kind='bar')

plt.xlabel('District')
plt.ylabel('Number of Properties')
plt.title('Number of Properties by District')
plt.xticks(range(len(district_counts)), ['Dongcheng', 'Fengtai', 'Tongzhou', 'Daxing', 'Fangshan', 'Changping', 'Chaoyang', 'Haidian', 'Shijingshan', 'Xicheng', 'Pinggu', 'Mentougou', 'Shunyi'], rotation=45)
plt.show()

# %%
# 我们分区块研究影响房价的显著因素
# 东城区
from folium.plugins import MarkerCluster
Mentougou_data = data[data['district'] == 12]
map_center = [Mentougou_data.iloc[0]['Lat'], Mentougou_data.iloc[0]['Lng']]
m = folium.Map(location=map_center, zoom_start=12)
# 创建一个 MarkerCluster 对象
marker_cluster = MarkerCluster().add_to(m)
# 遍历为每个点添加标记到 MarkerCluster 中，而不是直接添加到地图上
for index, row in Mentougou_data.iterrows():
    folium.Marker([row['Lat'], row['Lng']]).add_to(marker_cluster)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53637b2635d23d3ec62d77a898bd7347 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53637b2635d23d3ec62d77a898bd7347&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53637b2635d23d3ec62d77a898bd7347 = L.map(
#                 &quot;map_53637b2635d23d3ec62d77a898bd7347&quot;,
#                 {
#                     center: [39.939762, 116.121964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2aa4a5d779d49c1f45b9f723016aab7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2aa4a5d779d49c1f45b9f723016aab7.addTo(map_53637b2635d23d3ec62d77a898bd7347);
#
#
#             var marker_cluster_f6c855020f4178cb8bd1064ded6ced63 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_a466c8e4e31e24707087fa8bb3c55926 = L.marker(
#                 [39.939762, 116.121964],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_9c600e876e9bb5b0b12071a73f134a93 = L.marker(
#                 [39.937384, 116.122354],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_f096085caadf36b21a3bc4c0563ad195 = L.marker(
#                 [39.939762, 116.121964],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_638447707e5fe1f542d549320e5f02dd = L.marker(
#                 [39.932268, 116.12215],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_9df58b2d0bd8ee6a5f51185fee1dcf09 = L.marker(
#                 [39.949921, 116.111318],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_9716dd6b3b27968c614cb65aa332dab3 = L.marker(
#                 [39.949921, 116.111318],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_f173963a01f0173b491133024da9dfea = L.marker(
#                 [39.949921, 116.111318],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_cc6b8a79e1477ec81233315cae3e3c46 = L.marker(
#                 [39.932268, 116.12215],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_5d04069f3c04d26d92c11ee3311f64c0 = L.marker(
#                 [39.932268, 116.12215],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_08567b4c25a492d182dc64e1c63c9def = L.marker(
#                 [39.939735, 116.122491],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_8e0096646f4bda481efde11acee0e450 = L.marker(
#                 [39.937384, 116.122354],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_a42cdfcf606e3cccc1db659498a08ff4 = L.marker(
#                 [39.937384, 116.122354],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_235f653164c5644c2b07294392ab0721 = L.marker(
#                 [39.93386, 116.117019],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_9aabaa8ef5c8618220e2e4db0e2eae1f = L.marker(
#                 [39.93386, 116.117019],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_6cbd7957d72012058fae36b3316c451d = L.marker(
#                 [39.949921, 116.111318],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_fbb2a069a6c7e539a8f4f75fb69f81bd = L.marker(
#                 [39.949921, 116.111318],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178cb8bd1064ded6ced63);
#
#
#             var marker_992df0d857fec37212d64e13e2b242a0 = L.marker(
#                 [39.932268, 116.12215],
#                 {}
#             ).addTo(marker_cluster_f6c855020f4178c

# %%
from folium.plugins import HeatMap
# 东城区
# 我们先观察房屋价格在地理空间中的分布情况
map_center = [Mentougou_data.iloc[0]['Lat']-0.03, Mentougou_data.iloc[0]['Lng']]
m = folium.Map(location=map_center, zoom_start=12)
# 权重设置为每个点的price
heat_data = [[row['Lat'], row['Lng'], row['attractiveness']] for index, row in Mentougou_data.iterrows()]
# 创建热度图并添加到地图上，使用price作为权重
HeatMap(heat_data,blur=4, radius=8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae53e6164b461e9891611cfabecc0d95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae53e6164b461e9891611cfabecc0d95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae53e6164b461e9891611cfabecc0d95 = L.map(
#                 &quot;map_ae53e6164b461e9891611cfabecc0d95&quot;,
#                 {
#                     center: [39.909762, 116.121964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74e92e30799997d5bac7b8371155c1b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_74e92e30799997d5bac7b8371155c1b9.addTo(map_ae53e6164b461e9891611cfabecc0d95);
#
#
#             var heat_map_9de4fcaf34a2bef4620554235dc74ee2 = L.heatLayer(
#                 [[39.939762, 116.121964, 0.2077736574646339], [39.937384, 116.122354, 0.1970425307878954], [39.939762, 116.121964, 0.1849013413908345], [39.932268, 116.12215, 0.1704161516275237], [39.949921, 116.111318, 0.1803232156755024], [39.949921, 116.111318, 0.1942498741015428], [39.949921, 116.111318, 0.2042027194066749], [39.932268, 116.12215, 0.1814860596071968], [39.932268, 116.12215, 0.175424621160097], [39.939735, 116.122491, 0.2170306276610355], [39.937384, 116.122354, 0.1922629675410886], [39.937384, 116.122354, 0.1876207480657419], [39.93386, 116.117019, 0.1657556196493155], [39.93386, 116.117019, 0.1830975598589937], [39.949921, 116.111318, 0.2094858764821682], [39.949921, 116.111318, 0.182108684704482], [39.932268, 116.12215, 0.1606830563567275], [39.941152, 116.117724, 0.1850569976651558], [39.93386, 116.117019, 0.1750217460971478], [39.937888, 116.118409, 0.1845808725907613], [39.949921, 116.111318, 0.2043675319324268], [39.93386, 116.117019, 0.165389369592089], [39.934504, 116.119651, 0.1535045552350867], [39.949921, 116.111318, 0.1960902806391063], [39.934504, 116.119651, 0.1703612141189397], [39.937384, 116.122354, 0.1906789360435837], [39.937384, 116.122354, 0.1670283385981779], [39.939762, 116.121964, 0.1823742159959712], [39.937888, 116.118409, 0.1720368081307512], [39.941152, 116.117724, 0.1753330586457904], [39.937888, 116.118409, 0.1402554594149155], [39.932268, 116.12215, 0.1358329899739047], [39.93386, 116.117019, 0.152323398800531], [39.937888, 116.118409, 0.1882799981687497], [39.937888, 116.118409, 0.1744632147598773], [39.934504, 116.119651, 0.1903767797463718], [39.932268, 116.12215, 0.1333333333333333], [39.939762, 116.121964, 0.1654534633521036], [39.949921, 116.111318, 0.183060934853271], [39.932268, 116.12215, 0.1501350547086023], [39.932268, 116.12215, 0.1357872087167513], [39.937384, 116.122354, 0.1559492743670741], [39.939735, 116.122491, 0.1695646202444719], [39.934504, 116.119651, 0.1564620244471913], [39.939735, 116.122491, 0.1902211234720505], [39.939762, 116.121964, 0.1854873414823971], [39.934504, 116.119651, 0.152378336309115], [39.939762, 116.121964, 0.1694639014787346], [39.934504, 116.119651, 0.1466007416563658], [39.939762, 116.121964, 0.1492377420683972], [39.941152, 116.117724, 0.1622213065970791], [39.937384, 116.122354, 0.1626974316714736], [39.937888, 116.118409, 0.1571212745501991], [39.949921, 116.111318, 0.1714233392848967], [39.932268, 116.12215, 0.1389827404660532], [39.934504, 116.119651, 0.1597124937050771], [39.949921, 116.111318, 0.1388270841917319], [39.949921, 116.111318, 0.1429382410841001], [39.949921, 116.111318, 0.1428008973126402], [39.937384, 116.122354, 0.1515084924232019], [39.949921, 116.111318, 0.1385432403973813], [39.949921, 116.111318, 0.1285354575836652], [39.939735, 116.122491, 0.1642539944146866], [39.949921, 116.111318, 0.1380762715744174], [39.932268, 116.12215, 0.1281783637778693], [39.939735, 116.122491, 0.1754063086572357], [39.934504, 116.119651, 0.1450350226617223], [39.949921, 116.111318, 0.1467289291763951], [39.937384, 116.122354, 0.1279860824978254], [39.939735, 116.122491, 0.1582749622304628], [39.934504, 116.119651, 0.1250377695371514], [39.939762, 116.121964, 0.1637870255917227], [39.932268, 116.12215, 0.1252300508171954], [39.934504, 116.119651, 0.1393032092661264], [39.937888, 116.118409, 0.1361626150254086], [39.932268, 116.12215, 0.1213294877077324], [39.949921, 116.111318, 0.1427642723069175], [39.937888, 116.118409, 0.1710296204733782], [39.941152, 116.117724, 0.1630179004715469], [39.932268, 116.12215, 0.1308245204413313], [39.941152, 116.117724, 0.1305956141555647], [39.941152, 116.117724, 0.1225655816508721], [39.932268, 116.12215, 0.1324543331959895], [39.932268, 116.12215, 0.1348624273222542], [39.937384, 116.122354, 0.148560179462528], [39.937384, 116.122354, 0.1130064551572586], [39.939762, 116.121964, 0.1582932747333242], [39.937384, 116.12

# %%
# 我们在东城区的范围内研究房价的显著影响因素
# 东城区
import seaborn as sns
# 使用Seaborn绘制ladderRatio与attarctiveness的关系
sns.scatterplot(data=Mentougou_data, x='ladderRatio', y='attractiveness')
plt.title('Ladder Ratio vs Attractiveness in Dongcheng')
plt.xlabel('Ladder Ratio')
plt.ylabel('Attractiveness')
plt.show()

# %%
# 计算ladderRatio和attractiveness之间的相关系数
correlation_matrix = Mentougou_data[['ladderRatio', 'attractiveness']].corr()
# 打印相关系数矩阵
print(correlation_matrix)
# 从相关系数的角度看一般条件下ladderRatio在东城区不是一个显著影响房屋吸引力的因素
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000        0.046307
# attractiveness     0.046307        1.000000

# %%
# 我们再观察东城区的房价与楼层高度的关系
high_floor = Mentougou_data[Mentougou_data['floor'] > 10]
low_floor = Mentougou_data[Mentougou_data['floor'] <= 10]
print("东城区高层建筑共{high_floor}个，低层建筑共{low_floor}个,高层建筑占比为{high_floor_ratio:.2f}%".format(high_floor=len(high_floor), low_floor=len(low_floor), high_floor_ratio=len(high_floor)/len(Mentougou_data)*100))
# Out:
# 东城区高层建筑共558个，低层建筑共886个,高层建筑占比为38.64%

# %%
# 绘制饼图
plt.figure(figsize=(8, 8))
plt.pie([len(high_floor), len(low_floor)], labels=['High Floor', 'Low Floor'], autopct='%1.1f%%', startangle=140)
plt.title('Dongcheng Building Type Distribution')
plt.show()

# %%
# 计算floor和attractivness之间的相关系数
correlation_matrix = Mentougou_data[['floor', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                    floor  attractiveness
# floor           1.000000        0.302669
# attractiveness  0.302669        1.000000

# %%
# 我们在东城区的范围内研究房价的显著影响因素
# 东城区
# 使用Seaborn绘制ladderRatio与attarctiveness的关系
sns.scatterplot(data=Mentougou_data, x='floor', y='attractiveness')
plt.title('Floor vs Attarctiveness in Dongcheng')
plt.xlabel('Floor')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 发现在东城区中整体上floor和房屋的受欢迎程度没有关联
# 计算在高层条件下ladderRatio和attractiveness之间的相关系数
correlation_matrix = high_floor[['ladderRatio', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000        0.136514
# attractiveness     0.136514        1.000000

# %%
correlation_matrix = low_floor[['ladderRatio', 'attractiveness']].corr()
print(correlation_matrix)
# 对于低层建筑, ladderRatio和attractiveness之间的关联性相较于高层建筑要更弱,虽然面对高层建筑时人们会考虑人均楼梯数目但总体来说不显著
# Out:
#                 ladderRatio  attractiveness
# ladderRatio        1.000000       -0.063993
# attractiveness    -0.063993        1.000000

# %%
sns.scatterplot(data=Mentougou_data, x='communityAverage', y='attractiveness')
plt.title('CommunityAverage vs Attarctiveness in Dongcheng')
plt.xlabel('CommunityAverage')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 研究communityAverage与attractiveness之间的关联度
correlation_matrix = Mentougou_data[['communityAverage', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   communityAverage  attractiveness
# communityAverage          1.000000        0.349934
# attractiveness            0.349934        1.000000

# %%
sns.scatterplot(data=Mentougou_data, x='totalRoom', y='attractiveness')
plt.title('TotalRoom vs Attarctiveness in Dongcheng')
plt.xlabel('TotalRoom')
plt.ylabel('Attarctiveness')
plt.show()

# %%
# 研究totalRoom与attractiveness之间的关联度
correlation_matrix = Mentougou_data[['totalRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 totalRoom  attractiveness
# totalRoom        1.000000        0.204634
# attractiveness   0.204634        1.000000

# %%
# 研究totalRoom与attractiveness之间的关联度
correlation_matrix = Mentougou_data[['totalRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 totalRoom  attractiveness
# totalRoom        1.000000        0.204634
# attractiveness   0.204634        1.000000

# %%
# 分别计算每种房间的总数
total_livingRoom = Mentougou_data['livingRoom'].sum()
total_drawingRoom = Mentougou_data['drawingRoom'].sum()
total_kitchen = Mentougou_data['kitchen'].sum()
total_bathroom = Mentougou_data['bathRoom'].sum()
# 将计算结果合并为一个新的Series
room_totals = pd.Series({
    'Living Room': total_livingRoom,
    'Drawing Room': total_drawingRoom,
    'Kitchen': total_kitchen,
    'Bathroom': total_bathroom
})
room_totals.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution in Dongcheng')
plt.ylabel('')
plt.show()

# %%
# 我们从一般的角度出发研究房间类型对吸引力的影响
correlation_matrix = Mentougou_data[['bathRoom','kitchen','drawingRoom','livingRoom' ,'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  livingRoom  attractiveness
# bathRoom        1.000000 -0.019227     0.432821    0.595063        0.008246
# kitchen        -0.019227  1.000000    -0.132673    0.021460        0.553870
# drawingRoom     0.432821 -0.132673     1.000000    0.461262       -0.099080
# livingRoom      0.595063  0.021460     0.461262    1.000000        0.036786
# attractiveness  0.008246  0.553870    -0.099080    0.036786        1.000000

# %%
big_family = Mentougou_data[Mentougou_data['livingRoom'] >= 3]
# 我们再进一步研究大的家庭对不同种类房间的需求
correlation_matrix = big_family[['bathRoom','kitchen','drawingRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  attractiveness
# bathRoom        1.000000 -0.091565     0.434738       -0.133287
# kitchen        -0.091565  1.000000    -0.207662        0.544319
# drawingRoom     0.434738 -0.207662     1.000000       -0.184657
# attractiveness -0.133287  0.544319    -0.184657        1.000000

# %%
small_family = Mentougou_data[Mentougou_data['livingRoom'] < 3]
correlation_matrix = small_family[['bathRoom','kitchen','drawingRoom', 'attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 bathRoom   kitchen  drawingRoom  attractiveness
# bathRoom        1.000000 -0.036976     0.059936       -0.024805
# kitchen        -0.036976  1.000000    -0.145963        0.557740
# drawingRoom     0.059936 -0.145963     1.000000       -0.138320
# attractiveness -0.024805  0.557740    -0.138320        1.000000

# %%
# 交易时房龄对吸引力的影响
correlation_matrix = Mentougou_data[['constructionTime','houseAge','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   constructionTime  houseAge  attractiveness
# constructionTime          1.000000 -0.963065        0.209155
# houseAge                 -0.963065  1.000000       -0.009809
# attractiveness            0.209155 -0.009809        1.000000

# %%
correlation_matrix = Mentougou_data[['houseCondition','houseAge','constructionTime','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                   houseCondition  houseAge  constructionTime  attractiveness
# houseCondition          1.000000 -0.443386          0.437027        0.029015
# houseAge               -0.443386  1.000000         -0.963065       -0.009809
# constructionTime        0.437027 -0.963065          1.000000        0.209155
# attractiveness          0.029015 -0.009809          0.209155        1.000000

# %%
correlation_matrix = high_floor[['elevator','attractiveness']].corr()
print(correlation_matrix)
# Out:
#                 elevator  attractiveness
# elevator             NaN             NaN
# attractiveness       NaN             1.0

# %%
type_mapping = {
    1: 'tower',
    2: 'bungalow',
    3: 'combination of plate and tower',
    4: 'plate'
}
Mentougou_data['buildingType'] = Mentougou_data['buildingType'].map(type_mapping)
building_type_counts = Mentougou_data['buildingType'].value_counts()
building_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Building Type Distribution')
plt.ylabel('')
plt.show()
# Out:
# C:\Users\86187\AppData\Local\Temp\ipykernel_9748\905806474.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mentougou_data['buildingType'] = Mentougou_data['buildingType'].map(type_mapping)

# %%
# 计算每种房屋建筑结构类型的attractiveness平均值
attractiveness_avg = Mentougou_data.groupby('buildingType')['attractiveness'].mean().sort_values(ascending=False)
print(attractiveness_avg)
attractiveness_avg.plot(kind='bar')
plt.title('Average Attractiveness by House Type')
plt.xlabel('Building Type')
plt.ylabel('Average Attractiveness')
plt.show()
# Out:
# buildingType
# tower                             0.305932
# combination of plate and tower    0.256651
# plate                             0.250490
# Name: attractiveness, dtype: float64

# %%
Mentougou_data= Mentougou_data[Mentougou_data['buildingStructure']!=1]
Mentougou_data['buildingStructure']
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 8         6
#          ..
# 296820    2
# 296853    6
# 297066    2
# 297211    2
# 297586    2
# Name: buildingStructure, Length: 1444, dtype: int64

# %%
type_mapping = {
    2:"mixed",
    3:"brick and wood", 
    4:"brick and concrete", 
    5:"steel", 
    6:"steel-concrete composite"
}
Mentougou_data['buildingStructure'] = Mentougou_data['buildingStructure'].map(type_mapping)
building_type_counts = Mentougou_data['buildingStructure'].value_counts()
explode_values = (0, 0, 0.3, 0.2, 0.1)
building_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Building Structure Distribution')
plt.ylabel('')
plt.show()

# %%
# 计算每种房屋建筑结构类型的attractiveness平均值
attractiveness_avg = Mentougou_data.groupby('buildingStructure')['attractiveness'].mean().sort_values(ascending=False)
print(attractiveness_avg)
attractiveness_avg.plot(kind='bar')
plt.title('Average Attractiveness by Building Structure')
plt.xlabel('Building Structure')
plt.ylabel('Average Attractiveness')
plt.show()
# Out:
# buildingStructure
# steel-concrete composite    0.270584
# mixed                       0.236936
# brick and concrete          0.236380
# Name: attractiveness, dtype: float64
